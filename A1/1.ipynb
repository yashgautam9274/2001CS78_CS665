# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # ETT plotting

# %%
ETTh1 = 'ETT-small/ETTh1.csv'
ETTh2 = 'ETT-small/ETTh2.csv'
ETTm1 = 'ETT-small/ETTm1.csv'
ETTm2 = 'ETT-small/ETTm2.csv'

df_ETTh1 = pd.read_csv(ETTh1)
df_ETTh2 = pd.read_csv(ETTh2)
df_ETTm1 = pd.read_csv(ETTm1)
df_ETTm2 = pd.read_csv(ETTm2)
 
print(df_ETTh1)
# Out:
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
#               OT
# 0      30.531000
# 1      27.787001
# 2      27.787001
# 3      25.044001
# 4      21.948000
# ...

# %%
## OT plotting ETTh1 
plt.plot(df_ETTh1['OT'])

# %%
## OT plotting ETTh2 
plt.plot(df_ETTh2['OT'])

# %%
## OT plotting ETTm1 
plt.plot(df_ETTm1['OT'])

# %%
## OT plotting ETTm2 
plt.plot(df_ETTm2['OT'])

# %% [markdown]
# # ECL plotting

# %%
ecl = 'electricity/electricity.csv'

df_ecl = pd.read_csv(ecl)

# %%
df_ecl.head()
# Out:
#                   date     0     1      2      3      4       5     6       7  \
# 0  2016-07-01 02:00:00  14.0  69.0  234.0  415.0  215.0  1056.0  29.0   840.0
# 1  2016-07-01 03:00:00  18.0  92.0  312.0  556.0  292.0  1363.0  29.0  1102.0
# 2  2016-07-01 04:00:00  21.0  96.0  312.0  560.0  272.0  1240.0  29.0  1025.0
# 3  2016-07-01 05:00:00  20.0  92.0  312.0  443.0  213.0   845.0  24.0   833.0
# 4  2016-07-01 06:00:00  22.0  91.0  312.0  346.0  190.0   647.0  16.0   733.0
#
#        8  ...    311    312      313     314     315   316   317     318  \
# 0  226.0  ...  676.0  372.0  80100.0  4719.0  5002.0  48.0  38.0  1558.0
# 1  271.0  ...  805.0  452.0  95200.0  4643.0  6617.0  65.0  47.0  2177.0
# 2  270.0  ...  817.0  430.0  96600.0  4285.0  6571.0  64.0  43.0  2193.0
# 3  179.0  ...  801.0  291.0  94500.0  4222.0  6365.0  65.0  39.0  1315.0
# 4  186.0  ...  807.0  279.0  91300.0  4116.0  6298.0  75.0  40.0  1378.0
#
#      319      OT
# 0  182.0  2162.0
# 1  253.0  2835.0
# ...

# %%
plt.plot(df_ecl['OT'])

# %% [markdown]
# # Weather plotting

# %%
weather = 'weather/weather.csv'

weather_df = pd.read_csv(weather)
weather_df.head()
# Out:
#                   date  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  2020-01-01 00:10:00   1008.89      0.71    273.18        -1.33    86.1
# 1  2020-01-01 00:20:00   1008.76      0.75    273.22        -1.44    85.2
# 2  2020-01-01 00:30:00   1008.66      0.73    273.21        -1.48    85.1
# 3  2020-01-01 00:40:00   1008.64      0.37    272.86        -1.64    86.3
# 4  2020-01-01 00:50:00   1008.61      0.33    272.82        -1.50    87.4
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  ...  wv (m/s)  \
# 0          6.43          5.54          0.89       3.42  ...      1.02
# 1          6.45          5.49          0.95       3.39  ...      0.43
# 2          6.44          5.48          0.96       3.39  ...      0.61
# 3          6.27          5.41          0.86       3.35  ...      1.11
# 4          6.26          5.47          0.79       3.38  ...      0.49
#
#    max. wv (m/s)  wd (deg)  rain (mm)  raining (s)  SWDR (W/m�)  \
# ...

# %%
plt.plot(weather_df['OT'])
